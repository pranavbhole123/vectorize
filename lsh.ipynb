# %%
import numpy as np
import random
from numpy.linalg import norm
from numpy import array

#global variables
dim =6
length =1000000
p = 10 # number of hash tables to be geneerated

# %%
def genhyp():
    v = []
    for i in range(dim):
        v.append(np.random.rand() * 2 - 1)  
    return v

def dotprod(v , u):
    sum=0
    for i in range(dim):
        sum += v[i]*u[i]
    return sum

def hashp(points,k):
    n = length
    dicty={}
    v=[]
    for i in range(k):
        v.append(genhyp())

    for i in range(n):
        s=""
        for j in range(k):
            p = dotprod(points[i],v[j])
            if(p>=0):
                s+="1"
            else:
                s+="0"
        if s not in dicty:
            dicty[s]=[]
        dicty[s].append(points[i])
    return dicty,v

def print_keys_and_lengths(hash_dict):
    for key, value_list in hash_dict.items():
        print("Key:", key)
        print("Length of values:",len(value_list) )
        print()

# %%
def generate_matrix(k):
    # Create a matrix with 1000 rows and k columns
    matrix = [[np.random.uniform(-1, 1) for _ in range(k)] for _ in range(1000000)]
    return matrix


# Example: generate a matrix with 5 columns
result_matrix = generate_matrix(dim)


res,planes=hashp(result_matrix,6) # here 4 is number of hyperplanes nee
print_keys_and_lengths(res)
# Out:
# Key: 001010
# Length of values: 59269
#
# Key: 101000
# Length of values: 81490
#
# Key: 111111
# Length of values: 13593
#
# Key: 001101
# Length of values: 2673
#
# Key: 000110
# Length of values: 55008
#
# Key: 000010
# Length of values: 42812
#
# Key: 000000
# Length of values: 13402
#
# Key: 111001
# Length of values: 55290
#
# Key: 000100
# Length of values: 13586
#
# Key: 010110
# Length of values: 57093
#
# Key: 110101
# Length of values: 59561
#
# Key: 110111
# Length of values: 22535
#
# Key: 111110
# Length of values: 3349
#
# Key: 101001
# Length of values: 57663
#
# Key: 011100
# Length of values: 2346
#
# Key: 010111
# Length of values: 81565
#
# Key: 101010
# Length of values: 36915
#
# Key: 000001
# Length of values: 3309
#
# Key: 111101
# Length of values: 42478
#
# Key: 001000
# Length of values: 22510
#
# Key: 100001
# Length of values: 17671
#
# Key: 111011
# Length of values: 13430
#
# Key: 001100
# Length of values: 1581
#
# Key: 111010
# Length of values: 20460
#
# Key: 010101
# Length of values: 36997
#
# Key: 111000
# Length of values: 15026
#
# Key: 000111
# Length of values: 15030
#
# Key: 100011
# Length of values: 2445
#
# Key: 011101
# Length of values: 7268
#
# Key: 100101
# Length of values: 13537
#
# Key: 010100
# Length of values: 4068
#
# Key: 010010
# Length of values: 1843
#
# Key: 001001
# Length of values: 5475
#
# Key: 011110
# Length of values: 17391
#
# Key: 011010
# Length of values: 13359
#
# Key: 110001
# Length of values: 2833
#
# Key: 100000
# Length of values: 11579
#
# Key: 110010
# Length of values: 2628
#
# Key: 000101
# Length of values: 20925
#
# Key: 100010
# Length of values: 7288
#
# Key: 011111
# Length of values: 11710
#
# Key: 011001
# Length of values: 804
#
# Key: 010011
# Length of values: 258
#
# Key: 000011
# Length of values: 2471
#
# Key: 110110
# Length of values: 5611
#
# Key: 100100
# Length of values: 761
#
# Key: 001110
# Length of values: 2714
#
# Key: 110000
# Length of values: 732
#
# Key: 101101
# Length of values: 1993
#
# Key: 100111
# Length of values: 1352
#
# Key: 111100
# Length of values: 2362
#
# Key: 100110
# Length of values: 743
#
# Key: 001011
# Length of values: 1198
#
# Key: 110011
# Length of values: 1522
#
# Key: 011000
# Length of values: 1438
#
# Key: 101011
# Length of values: 4045
#
# Key: 011011
# Length of values: 853
#
# Key: 001111
# Length of values: 690
#
# Key: 101100
# Length of values: 260
#
# Key: 101111
# Length of values: 28
#
# Key: 110100
# Length of values: 1054
#
# Key: 101110
# Length of values: 44
#
# Key: 010001
# Length of values: 42
#
# Key: 010000
# Length of values: 34

# %%
print(len(res))
# Out:
# 64

# %%
y=[] # list of all dictionaries
z=[] # list of all planes
for i in range(p):
    temp1,temp2 = hashp(result_matrix,6)
    y.append(temp1)
    z.append(temp2)

# niw to search for query point we will have to search through

def search(dic_arr, plan,query,k): # k is the number of hyperplanes
    count=0
    maxy=-1
    res=None
    for i in range(p):
        
        s=""
        for j in range(k):
            
            temp = dotprod(query,plan[i][j])
            if(temp>=0):
                s+="1"
            else:
                s+="0"
        

        if s in dic_arr[i]:       
            for items in dic_arr[i][s]:
                count+=1
                cosine = np.dot(query,items)/(norm(items)*norm(query))
                if cosine>maxy:
                    res = items
                    maxy=cosine

    return maxy,res,count

# %%
query=[np.random.uniform(-1, 1) for _ in range(dim)]
#query =[0.9138841855388333, 0.8785912255929269, 0.8774993124064223, -0.7660173624999667, 0.6886402041331372, 0.5244560683917316]
print(query)
res1,res2,comp = search(y,z,query,6)
print(res1,res2,comp)
# Out:
# [0.9227733810665566, -0.024864436680192892, -0.772875289432944, 0.2814655313690759, -0.8751326889935904, 0.03269197696179704]
# 0.9972237490911985 [0.9139317712180559, 0.02718390233747292, -0.9042676619255778, 0.3156816495172463, -0.951823482919798, 0.04386682401654429] 399508

# %% [markdown]
# get the intitution of probability that when will we miss an event
